# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandradithya8/Machine-Learning/blob/master/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#VISUALIZING STATISTICAL RELATIONSHIPS

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
a=sns.load_dataset("flights") #from github-https://github.com/mwaskom/seaborn-data/blob/master/flights.csv
sns.relplot(x="passengers",y="month",data=a)

# %%
a=sns.load_dataset("flights") #from github-https://github.com/mwaskom/seaborn-data/blob/master/flights.csv
sns.relplot(x="passengers",y="month",data=a,hue="year")#scatter

# %%
b=sns.load_dataset("tips")
sns.relplot(x="time",y="tip",data=b,kind="line")

# %%
#PLOTTING WITH CATEGORICAL DATA
sns.catplot(x="day",y="total_bill",data=b)

# %%
sns.catplot(x="day",y="total_bill",data=b,kind="violin")

# %%
sns.catplot(x="day",y="total_bill",data=b,kind="boxen")

# %%
#VISUALIZING THE DISTRIBUTION OF DATASET
from scipy import stats

# %%
c=np.random.normal(loc=5,size=100,scale=2,)
sns.distplot(c)#univariate

# %%
 #MULTI PLOT GRID
 a=sns.load_dataset("iris")
b=sns.FacetGrid(a,col="species")
b.map(plt.hist,"sepal_length")

# %%
a=sns.load_dataset("flights")
b=sns.PairGrid(a)
b.map(plt.scatter)
